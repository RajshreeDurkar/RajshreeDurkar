# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as nm
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("heart_disease_uci.csv")
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
df.head()
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0

# %%
df.tail()
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
#               restecg  thalch  exang  oldpeak slope  ca          thal  num
# 915  st-t abnormality   154.0  False      0.0   NaN NaN           NaN    1
# 916  st-t abnormality     NaN    NaN      NaN   NaN NaN           NaN    0
# 917  st-t abnormality   100.0  False      0.0   NaN NaN  fixed defect    2
# 918    lv hypertrophy     NaN    NaN      NaN   NaN NaN           NaN    0
# 919    lv hypertrophy    93.0   True      0.0   NaN NaN           NaN    1

# %%
df.describe()
# Out:
#                id         age    trestbps        chol      thalch     oldpeak  \
# count  920.000000  920.000000  861.000000  890.000000  865.000000  858.000000
# mean   460.500000   53.510870  132.132404  199.130337  137.545665    0.878788
# std    265.725422    9.424685   19.066070  110.780810   25.926276    1.091226
# min      1.000000   28.000000    0.000000    0.000000   60.000000   -2.600000
# 25%    230.750000   47.000000  120.000000  175.000000  120.000000    0.000000
# 50%    460.500000   54.000000  130.000000  223.000000  140.000000    0.500000
# 75%    690.250000   60.000000  140.000000  268.000000  157.000000    1.500000
# max    920.000000   77.000000  200.000000  603.000000  202.000000    6.200000
#
#                ca         num
# count  309.000000  920.000000
# mean     0.676375    0.995652
# std      0.935653    1.142693
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    1.000000
# 75%      1.000000    2.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %%
df.columns
# Out:
# Index(['id', 'age', 'sex', 'dataset', 'cp', 'trestbps', 'chol', 'fbs',
#        'restecg', 'thalch', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %%
#use for missing values
df.isnull().sum()
# Out:
# id            0
# age           0
# sex           0
# dataset       0
# cp            0
# trestbps     59
# chol         30
# fbs          90
# restecg       2
# thalch       55
# exang        55
# oldpeak      62
# slope       309
# ca          611
# thal        486
# num           0
# dtype: int64

# %%
df.fillna(df.mean(), inplace=True)

# %%
#* Null
df.isnull().sum()
# Out:
# id            0
# age           0
# sex           0
# dataset       0
# cp            0
# trestbps      0
# chol          0
# fbs           0
# restecg       2
# thalch        0
# exang         0
# oldpeak       0
# slope       309
# ca            0
# thal        486
# num           0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# id          0
# age         0
# sex         0
# dataset     0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalch      0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
# !pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
# Out:
# ...
#   Attempting uninstall: wordcloud
#     Found existing installation: wordcloud 1.8.2.2
#     Uninstalling wordcloud-1.8.2.2:
#       Successfully uninstalled wordcloud-1.8.2.2
# ...

# %%
df.head()
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0

# %%
plt.hist(df['age'])
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# visualizing null values if it exists
plt.figure(figsize=(22,10))

plt.xticks(size=20,color='grey')
plt.tick_params(size=12,color='grey')

plt.title('Finding Null Values Using Heatmap\n',color='red',size=30)

sns.heatmap(df.isnull(),
            yticklabels=False,
            cbar=False,
            cmap='PuBu_r',
            )
# Out:
# <AxesSubplot:title={'center':'Finding Null Values Using Heatmap\n'}>

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True,cmap="magma",fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                 id       age  trestbps      chol    thalch   oldpeak  \
# id        1.000000  0.092275  0.055970 -0.663297 -0.507115 -0.072579
# age       0.092275  1.000000  0.301845 -0.009205 -0.354478  0.161915
# trestbps  0.055970  0.301845  1.000000  0.014993 -0.080784  0.167918
# chol     -0.663297 -0.009205  0.014993  1.000000  0.416848  0.144096
# thalch   -0.507115 -0.354478 -0.080784  0.416848  1.000000 -0.178983
# oldpeak  -0.072579  0.161915  0.167918  0.144096 -0.178983  1.000000
# ca        0.009120  0.321206  0.083902  0.052962 -0.198424  0.266095
# num       0.263814  0.223177  0.160507 -0.256971 -0.456309  0.392207
#
#                 ca       num
# id        0.009120  0.263814
# age       0.321206  0.223177
# trestbps  0.083902  0.160507
# chol      0.052962 -0.256971
# thalch   -0.198424 -0.456309
# oldpeak   0.266095  0.392207
# ca        1.000000  0.456754
# num       0.456754  1.000000

# %%
x=df.iloc[:,:15]
y=df.iloc[:,-1]
x
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 890  891   53    Male  VA Long Beach     asymptomatic     124.0  243.0  False
# 891  892   37    Male  VA Long Beach      non-anginal     118.0  240.0  False
# 892  893   67    Male  VA Long Beach     asymptomatic     140.0  219.0  False
# 902  903   55    Male  VA Long Beach     asymptomatic     120.0  226.0  False
# 903  904   56    Male  VA Long Beach     asymptomatic     130.0  203.0   True
#
# ...

# %%
y
# Out:
# 0      0
# 1      2
# 2      1
# 3      0
# 4      0
#       ..
# 890    1
# 891    0
# 892    3
# 902    1
# 903    1
# Name: num, Length: 385, dtype: int64

# %%
df['sex']
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 890      Male
# 891      Male
# 892      Male
# 902      Male
# 903      Male
# Name: sex, Length: 385, dtype: object

# %%
# Label Encoding
df_cat=df.select_dtypes(["object"])

from sklearn.preprocessing import LabelEncoder
for col in df_cat:
    le=LabelEncoder()
    df_cat[col]=le.fit_transform(df_cat[col])

# %%
le=LabelEncoder()
df["sex"]=le.fit_transform(df["sex"])
df
# Out:
#       id  age  sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    1      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    1      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    1      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    1      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41    0      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...  ...            ...              ...       ...    ...    ...
# 890  891   53    1  VA Long Beach     asymptomatic     124.0  243.0  False
# 891  892   37    1  VA Long Beach      non-anginal     118.0  240.0  False
# 892  893   67    1  VA Long Beach     asymptomatic     140.0  219.0  False
# 902  903   55    1  VA Long Beach     asymptomatic     120.0  226.0  False
# 903  904   56    1  VA Long Beach     asymptomatic     130.0  203.0   True
#
# ...

# %% [markdown]
# # Data Visualization

# %%
sns.set_style('darkgrid')
sns.set_palette('Set1')

# %%
df2 = df.copy()

# %%
def chng(sex):
    if sex == 0:
        return 'fema'
    else:
        return 'male'
df2['sex'] = df2['sex'].apply(chng)

# %%
def chng2(prob):
    if prob == 0:
        return 'Heart Disease'
    else:
        return 'No Heart Disease'
df2['num'] = df2['num'].apply(chng2)

# %%
sns.countplot(data= df2, x='sex',hue='num')
plt.title('gender v/s numt\n')
# Out:
# Text(0.5, 1.0, 'gender v/s numt\n')

# %%
sns.countplot(data= df2, x='cp',hue='num',color="skyblue")
plt.title('Chest Pain Type v/s target\n')
# Out:
# Text(0.5, 1.0, 'Chest Pain Type v/s target\n')

# %%
sns.countplot(data= df2, x='sex',hue='thal')
plt.title('Gender v/s Thalassemia\n')
# Out:
# Text(0.5, 1.0, 'Gender v/s Thalassemia\n')

# %%
sns.countplot(data= df2, x='slope',hue='num')
plt.title('Slope v/s num')
# Out:
# Text(0.5, 1.0, 'Slope v/s num')

# %%
sns.countplot(data= df2, x='exang',hue='thal')
plt.title('exang v/s Thalassemia\n')
# Out:
# Text(0.5, 1.0, 'exang v/s Thalassemia\n')

# %%
plt.figure(figsize=(16,7))
sns.distplot(df[df['num']==0]['age'],kde=False,bins=50)
plt.title('Age of Heart Diseased Patients\n')
# Out:
# Text(0.5, 1.0, 'Age of Heart Diseased Patients\n')

# %%
plt.figure(figsize=(16,7))
sns.distplot(df[df['num']==0]['chol'],kde=False,bins=40)
plt.title('Chol of Heart Diseased Patients\n')
# Out:
# Text(0.5, 1.0, 'Chol of Heart Diseased Patients\n')

# %%
sns.boxplot(data=df2,x='num',y='age')
# Out:
# <AxesSubplot:xlabel='num', ylabel='age'>

# %%
plt.figure(figsize=(14,8))
sns.violinplot(data=df2,x='ca',y='age',hue='num',color="green")
# Out:
# <AxesSubplot:xlabel='ca', ylabel='age'>

# %%
sns.boxplot(data=df2,x='cp',y='thalch',hue='num')
# Out:
# <AxesSubplot:xlabel='cp', ylabel='thalch'>

# %%
plt.figure(figsize=(10,7))
sns.boxplot(data=df2,x='fbs',y='trestbps',hue='num')
# Out:
# <AxesSubplot:xlabel='fbs', ylabel='trestbps'>

# %%
plt.figure(figsize=(10,7))
sns.violinplot(data=df2,x='exang',y='oldpeak',hue='num',color="lightpink")
# Out:
# <AxesSubplot:xlabel='exang', ylabel='oldpeak'>

# %%
plt.figure(figsize=(10,7))
sns.boxplot(data=df2,x='slope',y='thalch',hue='num')
# Out:
# <AxesSubplot:xlabel='slope', ylabel='thalch'>

# %%
sns.violinplot(data=df2,x='num',y='thalch',color="black")
# Out:
# <AxesSubplot:xlabel='num', ylabel='thalch'>

# %%
sns.violinplot(data=df2,x='thal',y='oldpeak',hue='num')
# Out:
# <AxesSubplot:xlabel='thal', ylabel='oldpeak'>

# %%
df3 = df[df['num'] == 0 ][['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalch',
       'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num']] # num 0 - people with heart disease

# %%
pal = sns.light_palette("blue", as_cmap=True)


print('Age vs trestbps(Heart Diseased Patinets)')
sns.jointplot(data=df3,
              x='age',
              y='trestbps',
              kind='hex',
              cmap='Blues'
           
              )
# Out:
# Age vs trestbps(Heart Diseased Patinets)

# %%
sns.jointplot(data=df3,
              x='chol',
              y='age',
              kind='kde',
              cmap='PuBu'
              )

# %%
sns.jointplot(data=df3,
              x='chol',
              y='trestbps',
              kind='resid',
             
              )

# %%
sns.clustermap(df.corr(),annot=True)

# %%
df
# Out:
#       id  age  sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    1      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    1      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    1      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    1      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41    0      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...  ...            ...              ...       ...    ...    ...
# 890  891   53    1  VA Long Beach     asymptomatic     124.0  243.0  False
# 891  892   37    1  VA Long Beach      non-anginal     118.0  240.0  False
# 892  893   67    1  VA Long Beach     asymptomatic     140.0  219.0  False
# 902  903   55    1  VA Long Beach     asymptomatic     120.0  226.0  False
# 903  904   56    1  VA Long Beach     asymptomatic     130.0  203.0   True
#
# ...

# %%
# Classification

# %%
 # 70% training and 30% test
 # Training and testing split
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.3, random_state=1)

# %%
df.head()
# Out:
#    id  age  sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    1  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    1  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    1  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    1  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41    0  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0

# %% [markdown]
# # Converting Categorical Data into Numeric data

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder()

# %%
colname = df.select_dtypes(object).columns
colname
# Out:
# Index(['dataset', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'thal'], dtype='object')

# %%
df[colname]=oe.fit_transform(df[colname])
df
# Out:
#       id  age  sex  dataset   cp  trestbps   chol  fbs  restecg  thalch  \
# 0      1   63    1      0.0  3.0     145.0  233.0  2.0      0.0   150.0
# 1      2   67    1      0.0  0.0     160.0  286.0  0.0      0.0   108.0
# 2      3   67    1      0.0  0.0     120.0  229.0  0.0      0.0   129.0
# 3      4   37    1      0.0  2.0     130.0  250.0  0.0      1.0   187.0
# 4      5   41    0      0.0  1.0     130.0  204.0  0.0      0.0   172.0
# ..   ...  ...  ...      ...  ...       ...    ...  ...      ...     ...
# 890  891   53    1      3.0  0.0     124.0  243.0  0.0      1.0   122.0
# 891  892   37    1      3.0  2.0     118.0  240.0  0.0      0.0   165.0
# 892  893   67    1      3.0  0.0     140.0  219.0  0.0      2.0   122.0
# 902  903   55    1      3.0  0.0     120.0  226.0  0.0      0.0   127.0
# 903  904   56    1      3.0  0.0     130.0  203.0  2.0      1.0    98.0
#
#      exang  oldpeak  slope        ca  thal  num
# 0      0.0      2.3    0.0  0.000000   0.0    0
# ...

# %%
df
# Out:
#       id  age  sex  dataset   cp  trestbps   chol  fbs  restecg  thalch  \
# 0      1   63    1      0.0  3.0     145.0  233.0  2.0      0.0   150.0
# 1      2   67    1      0.0  0.0     160.0  286.0  0.0      0.0   108.0
# 2      3   67    1      0.0  0.0     120.0  229.0  0.0      0.0   129.0
# 3      4   37    1      0.0  2.0     130.0  250.0  0.0      1.0   187.0
# 4      5   41    0      0.0  1.0     130.0  204.0  0.0      0.0   172.0
# ..   ...  ...  ...      ...  ...       ...    ...  ...      ...     ...
# 890  891   53    1      3.0  0.0     124.0  243.0  0.0      1.0   122.0
# 891  892   37    1      3.0  2.0     118.0  240.0  0.0      0.0   165.0
# 892  893   67    1      3.0  0.0     140.0  219.0  0.0      2.0   122.0
# 902  903   55    1      3.0  0.0     120.0  226.0  0.0      0.0   127.0
# 903  904   56    1      3.0  0.0     130.0  203.0  2.0      1.0    98.0
#
#      exang  oldpeak  slope        ca  thal  num
# 0      0.0      2.3    0.0  0.000000   0.0    0
# ...

# %%
x=df.iloc[:,:15]
y=df.iloc[:,-1]

# %%
x
# Out:
#       id  age  sex  dataset   cp  trestbps   chol  fbs  restecg  thalch  \
# 0      1   63    1      0.0  3.0     145.0  233.0  2.0      0.0   150.0
# 1      2   67    1      0.0  0.0     160.0  286.0  0.0      0.0   108.0
# 2      3   67    1      0.0  0.0     120.0  229.0  0.0      0.0   129.0
# 3      4   37    1      0.0  2.0     130.0  250.0  0.0      1.0   187.0
# 4      5   41    0      0.0  1.0     130.0  204.0  0.0      0.0   172.0
# ..   ...  ...  ...      ...  ...       ...    ...  ...      ...     ...
# 890  891   53    1      3.0  0.0     124.0  243.0  0.0      1.0   122.0
# 891  892   37    1      3.0  2.0     118.0  240.0  0.0      0.0   165.0
# 892  893   67    1      3.0  0.0     140.0  219.0  0.0      2.0   122.0
# 902  903   55    1      3.0  0.0     120.0  226.0  0.0      0.0   127.0
# 903  904   56    1      3.0  0.0     130.0  203.0  2.0      1.0    98.0
#
#      exang  oldpeak  slope        ca  thal
# 0      0.0      2.3    0.0  0.000000   0.0
# ...

# %%
sns.pairplot(df,hue='cp')

# %%
#Feature Scaling:

from sklearn.preprocessing import StandardScaler
st_x = StandardScaler()
x_train = st_x.fit_transform(x_train)
xtest = st_x.transform(x_test)

# %%
#Fitting Decision Tree Classifier to the training set:

from sklearn.tree import DecisionTreeClassifier
classifier= DecisionTreeClassifier(criterion="entropy", random_state=1)
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=1)

# %%
#Predicting the test set result:

ypred = classifier.predict(x_test)

# %%
#Creating a confusion matrix:

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,ypred)
cm
# Out:
# array([[36, 13,  0,  0,  0],
#        [13,  8,  0,  0,  0],
#        [12,  8,  0,  0,  0],
#        [12, 10,  0,  0,  0],
#        [ 2,  2,  0,  0,  0]], dtype=int64)

# %%
print("Accuracy:",metrics.accuracy_score(ytest, ypred))
# Out:
# Accuracy: 0.3793103448275862
